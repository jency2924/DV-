# %%
import pandas as pd

# %%
df = pd.read_excel("/content/drive/MyDrive/AAPL.xlsx")

# %%
df.head()
# Out:
#         Date        Open        High         Low       Close   Adj Close  \
# 0 2014-09-29  100.589996  100.690002   98.040001   99.620003   93.514290
# 1 2014-10-06   99.949997  102.379997   98.309998  100.730003   94.556244
# 2 2014-10-13  101.330002  101.779999   95.180000   97.669998   91.683792
# 3 2014-10-20   98.320000  105.489998   98.220001  105.220001   98.771042
# 4 2014-10-27  104.849998  108.040001  104.699997  108.000000  101.380676
#
#       Volume
# 0  142718700
# 1  280258200
# 2  358539800
# 3  358532900
# 4  220230600

# %%
df.columns = df.columns.str.strip()

# %%
df.columns = df.columns.str.strip()

print("\nColumn Names:")
print(df.columns)
# Out:
# Column Names:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
cols = ["Open", "High", "Low", "Close", "Volume"]

for col in cols:
    df[col] = pd.to_numeric(df[col], errors="coerce")

df = df.dropna(subset=cols)

# %%
mean_vol = df["Volume"].mean()
std_vol = df["Volume"].std()

df["Volume_Anomaly"] = (
    abs(df["Volume"] - mean_vol) > 2 * std_vol
)

# %%
mean_return = df["Daily_Return"].mean()
variance_return = df["Daily_Return"].var()
std_return = df["Daily_Return"].std()

print("\nStock Return Statistics")
print("-----------------------")
print("Mean Return:", mean_return)
print("Variance:", variance_return)
print("Standard Deviation:", std_return)
# Out:
# Stock Return Statistics
# -----------------------
# Mean Return: 0.30716273695058094
# Variance: 12.289199177244166
# Standard Deviation: 3.5055954098047546

# %%
print("\nAnomalous Trading Days:")
print(
    df[df["Volume_Anomaly"]][
        ["Date", "Volume"]
    ]
)
# Out:
# Anomalous Trading Days:
#           Date     Volume
# 2   2014-10-13  358539800
# 3   2014-10-20  358532900
# 17  2015-01-26  465842700
# 21  2015-02-23  368216200
# 30  2015-04-27  420972300
# 44  2015-08-03  385000600
# 47  2015-08-24  500363000
# 69  2016-01-25  380336500
# 102 2016-09-12  388228200

# %%
print("\nCleaned Data:")
print(
    df[
        [
            "Date",
            "Open",
            "High",
            "Low",
            "Close",
            "Volume",
            "Price_Delta",
            "Daily_Return",
            "Volume_Anomaly"
        ]
    ].head(10)
)
# Out:
# Cleaned Data:
#         Date        Open        High         Low       Close     Volume  \
# 0 2014-09-29  100.589996  100.690002   98.040001   99.620003  142718700
# 1 2014-10-06   99.949997  102.379997   98.309998  100.730003  280258200
# 2 2014-10-13  101.330002  101.779999   95.180000   97.669998  358539800
# 3 2014-10-20   98.320000  105.489998   98.220001  105.220001  358532900
# 4 2014-10-27  104.849998  108.040001  104.699997  108.000000  220230600
# 5 2014-11-03  108.220001  110.300003  107.720001  109.010002  199952900
# 6 2014-11-10  109.019997  114.190002  108.400002  114.180000  205166700
# 7 2014-11-17  114.269997  117.570000  113.300003  116.470001  233414700
# 8 2014-11-24  116.849998  119.750000  116.620003  118.930000  181873900
# 9 2014-12-01  118.809998  119.250000  111.269997  115.000000  266589700
#
#    Price_Delta  Daily_Return  Volume_Anomaly
# 0    -0.969993     -0.964304           False
# 1     0.780006      0.780396           False
# 2    -3.660004     -3.611965            True
# 3     6.900001      7.017902            True
# 4     3.150002      3.004294           False
# 5     0.790001      0.729995           False
# 6     5.160003      4.733079           False
# 7     2.200004      1.925268           False
# 8     2.080002      1.780062           False
# 9    -3.809998     -3.206799           False
