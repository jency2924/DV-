# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/StudentsPerformance.csv")

# %%
df.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score', 'race/Ethnicity'],
#       dtype='object')

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
#
#   race/Ethnicity  total score  average score
# 0        group b          218      72.666667
# 1        group c          247      82.333333
# 2        group b          278      92.666667
# 3        group a          148      49.333333
# 4        group c          229      76.333333

# %%
df.isnull().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# race/Ethnicity                 0
# total score                    0
# average score                  0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
print("\nShape:")
print(df.shape)

print("\nColumn Names:")
print(df.columns)

print("\nData Types:")
print(df.dtypes)
# Out:
# Shape:
# (1000, 11)
#
# Column Names:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score', 'race/Ethnicity', 'total score', 'average score'],
#       dtype='object')
#
# Data Types:
# gender                          object
# race/ethnicity                  object
# parental level of education     object
# lunch                           object
# test preparation course         object
# math score                       int64
# reading score                    int64
# writing score                    int64
# race/Ethnicity                  object
# total score                      int64
# average score                  float64
# dtype: object

# %%
catagory_column = [
    "gender",
    "race/ethnicity",
    "parental level of education",
    "lunch",
    "test preparation course"
]

# %%
for col in catagory_column:
    df[col] = df[col].astype(str).str.strip().str.lower().str.title()

# %%
print(df[cat_cols].isnull().sum())
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# dtype: int64

# %%
score_columns = [
    "math score",
    "reading score",
    "writing score"
]

# %%
df["total score"] = (
    df["math score"]
    + df["reading score"]
    + df["writing score"]
)

# %%
df["average score"] = df["total score"] / 3

# %%
for col in score_columns:

    print("\nSubject:", col)

    print("Mean:", df[col].mean())

    print("Median:", df[col].median())

    print("Standard Deviation:", df[col].std())

    print("Q1:", df[col].quantile(0.25))

    print("Q2 (Median):", df[col].quantile(0.50))

    print("Q3:", df[col].quantile(0.75))
# Out:
# Subject: math score
# Mean: 66.089
# Median: 66.0
# Standard Deviation: 15.163080096009468
# Q1: 57.0
# Q2 (Median): 66.0
# Q3: 77.0
#
# Subject: reading score
# Mean: 69.169
# Median: 70.0
# Standard Deviation: 14.60019193725222
# Q1: 59.0
# Q2 (Median): 70.0
# Q3: 79.0
#
# Subject: writing score
# Mean: 68.054
# Median: 69.0
# Standard Deviation: 15.195657010869642
# Q1: 57.75
# Q2 (Median): 69.0
# Q3: 79.0
